# %%
import json
import pandas as pd

with open('/content/train_separate_questions.json', 'r') as f:
    complex_data = json.load(f)

simple_rows = []

for contract in complex_data['data']:
    for paragraph in contract['paragraphs']:
        for qas in paragraph['qas']:

            if not qas.get('answers'):
                continue

            raw_id = qas['id']
            category = raw_id.split('__')[1].rsplit('_', 1)[0]

            for answer in qas['answers']:
                clause_text = answer['text'].strip()

                if len(clause_text) > 10:
                    simple_rows.append({
                        'text': clause_text,
                        'category': category
                    })

train_df = pd.DataFrame(simple_rows).drop_duplicates(subset=['text']).reset_index(drop=True)

print(train_df.tail())
# Out:
#                                                    text  \
# 8901  Said books and records shall be maintained for...
# 8902  Company shall make said books available to Nor...
# 8903  Company agrees, at its own expense, to obtain ...
# 8904  Such insurance policy  shall be maintained wit...
# 8905  A copy of such insurance policy shall be provi...
#
#                        category
# 8901  Post-Termination Services
# 8902               Audit Rights
# 8903                  Insurance
# 8904                  Insurance
# 8905                  Insurance

# %%
import json
import pandas as pd

with open('/content/test.json', 'r') as f:
    complex_data = json.load(f)

simple_rows = []

for contract in complex_data['data']:
    for paragraph in contract['paragraphs']:
        for qas in paragraph['qas']:

            if not qas.get('answers'):
                continue

            raw_id = qas['id']
            category = raw_id.split('__')[1].rsplit('_', 1)[0]

            for answer in qas['answers']:
                clause_text = answer['text'].strip()

                if len(clause_text) > 10:
                    simple_rows.append({
                        'text': clause_text,
                        'category': category
                    })

test_df = pd.DataFrame(simple_rows).drop_duplicates(subset=['text']).reset_index(drop=True)

print(test_df.tail())
# Out:
#                                                    text            category
# 2159  To the extent that Contractor incorporates any...       License Grant
# 2160  EXCEPT WITH RESPECT TO CONTRACTOR'S OBLIGATION...  Uncapped Liability
# 2161  COMPANYS' MAXIMUM LIABILITY TO CONTRACTOR FOR ...    Cap On Liability
# 2162  NEITHER PARTY SHALL HAVE ANY LIABILITY TO THE ...    Cap On Liability
# 2163  Throughout the term of this Agreement, Contrac...           Insurance

# %%
import pandas as pd

train_df['is_valid'] = False
test_df['is_valid'] = True

full_df = pd.concat([train_df, test_df], ignore_index=True)

print(f"Total rows: {len(full_df)}")
print(f"Training rows: {len(train_df)}")
print(f"Testing rows: {len(test_df)}")
# Out:
# Total rows: 11070
# Training rows: 8906
# Testing rows: 2164

# %%
from fastai.text.all import *

dls = TextDataLoaders.from_df(
    full_df,
    text_col='text',
    label_col='category',
    valid_col='is_valid',
    bs=16
)

dls.show_batch(max_n=5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>text</th>
#       <th>category</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>xxbos xxmaj storage xxmaj fee ( payable if the source code exceeds one xxunk xxunk ) - xxrep 80 - xxmaj annual liability fee payable ( if appropriate ) - xxrep 80 - xxmaj release xxmaj fee ( plus ncc 's reasonable expenses ) x - xxrep 80 - \n\n ii xxmaj version 1 : xxmaj august 1997 \n\n ( c ) xxup ncc xxmaj escrow xxmaj international xxmaj limited 1997 xxup xxunk \n\n [ ncc xxmaj escrow xxmaj international logo ] \n\n▁ xxup single xxup licensee ( uk ) xxup escrow 2 xxrep 3 0 - xxrep 80 - xxup escrow xxup agreement : xxup dated : \n\n xxmaj between : \n\n ( 1 ) [ xxunk ] whose registered office is at [ xxunk ] ( xxunk : [ xxunk ] ) ( " the xxmaj owner " ) ; \n\n ( 2 ) [ xxunk ] whose</td>
#       <td>Source Code Escrow</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>xxbos xxmaj all sublicensing by xxmaj equifax and other members of the xxmaj equifax xxmaj group to any one of their customers shall be pursuant to written agreements with such customer , executed before or at the time of furnishing each copy of the xxmaj licensed xxmaj certegy xxmaj materials ( excluding the xxmaj utility xxmaj software xxmaj programs ) to such customer , and which provide at a minimum that such customer : \n\n▁ ( i ) receives only a personal , non - transferable and nonexclusive right to use such copy of the xxmaj licensed xxmaj certegy xxmaj materials ( excluding the xxmaj utility xxmaj software xxmaj programs ) ; \n\n▁ ( ii ) receives no title in the intellectual property contained in the xxmaj licensed xxmaj certegy xxmaj materials ( excluding the xxmaj utility xxmaj software xxmaj programs ) ; \n\n▁ ( xxrep 3 i ) will</td>
#       <td>License Grant</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>xxbos xxmaj effective as of the xxmaj initial xxmaj closing xxmaj date , the xxmaj purchaser will cause each xxmaj acquired xxmaj company and each xxmaj purchaser xxmaj assignee to grant , following each applicable xxmaj closing xxmaj date , to the xxmaj seller xxmaj parties , an irrevocable ( except as expressly set forth herein ) , non - sublicenseable ( except as expressly set forth herein ) , perpetual , fully paid - up , royalty - free , worldwide , non - transferable ( except as expressly set forth herein ) , non - exclusive license , under the xxmaj transferred xxup ip ( other than xxmaj trademarks and xxmaj patents ) that is or has been , on or prior to the xxmaj initial xxmaj closing xxmaj date , ( x ) used in connection with the xxmaj seller xxmaj business , ( y ) used</td>
#       <td>License Grant</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>xxbos xxmaj certegy hereby grants , and will cause the other members of the xxmaj certegy xxmaj group to grant , to xxmaj equifax a fully paid , non - exclusive , perpetual , worldwide , non - transferable license to use , modify , copy , improve , create xxmaj derivative xxmaj works and xxmaj equifax xxmaj enhancements from , and sublicense the xxmaj licensed xxmaj certegy xxmaj materials ( excluding the xxmaj utility xxmaj software xxmaj programs ) solely for use in the xxmaj equifax xxmaj business and as that business may evolve and change in the future , subject to the following : \n\n▁ ( i ) xxmaj equifax shall not sublicense , or otherwise disclose or distribute , or permit any xxmaj person to use , the xxmaj licensed xxmaj certegy xxmaj materials ( excluding the xxmaj utility xxmaj software xxmaj programs ) , except in</td>
#       <td>License Grant</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>xxbos xxmaj license xxmaj grants . \n\n 1 . revmed xxmaj license to xxup shp2 xxmaj inhibitors . xxmaj sanofi shall , effective upon any such termination of this xxmaj agreement , and hereby does , grant to revmed [ xxrep 3 * ] , under all [ xxrep 3 * ] , and [ xxrep 3 * ] , to [ xxrep 3 * ] . xxmaj notwithstanding the foregoing , [ xxrep 3 * ] shall not include [ xxrep 3 * ] , and [ xxrep 3 * ] shall include [ xxrep 3 * ] ( to the extent [ xxrep 3 * ] ) . \n\n 2 . revmed xxmaj license to xxmaj practice xxmaj certain xxmaj xxunk . xxmaj sanofi shall , effective upon any such termination of this xxmaj agreement , and hereby does , grant to revmed [ xxrep 3 * ]</td>
#       <td>License Grant</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn = text_classifier_learner(
    dls,
    AWD_LSTM,
    drop_mult=0.5,
    metrics=[accuracy]
)

# 3. Train the model (Fine-Tuning)
learn.fine_tune(5, base_lr=2e-2)
# Out:
# <style>
#     progress { appearance: none; border: none; border-radius: 4px; width: 300px;
#         height: 20px; vertical-align: middle; background: #e0e0e0; }
#
#     progress::-webkit-progress-bar { background: #e0e0e0; border-radius: 4px; }
#     progress::-webkit-progress-value { background: #2196F3; border-radius: 4px; }
#     progress::-moz-progress-bar { background: #2196F3; border-radius: 4px; }
#
#     progress:not([value]) {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px); }
#
#     progress.progress-bar-interrupted::-webkit-progress-value { background: #F44336; }
#     progress.progress-bar-interrupted::-moz-progress-value { background: #F44336; }
#     progress.progress-bar-interrupted::-webkit-progress-bar { background: #F44336; }
#     progress.progress-bar-interrupted::-moz-progress-bar { background: #F44336; }
#     progress.progress-bar-interrupted { background: #F44336; }
#
#     table.fastprogress { border-collapse: collapse; margin: 1em 0; font-size: 0.9em; }
#     table.fastprogress th, table.fastprogress td { padding: 8px 12px; border: 1px solid #ddd; text-align: left; }
#     table.fastprogress thead tr { background: #f8f9fa; font-weight: bold; }
#     table.fastprogress tbody tr:nth-of-type(even) { background: #f8f9fa; }
# </style>
# <div><progress max="105067061" value="105070592"></progress> 100.00% [105070592/105067061 00:03&lt;00:00]</div>
# <div><table class="fastprogress"><thead><tr><th>epoch</th><th>train_loss</th><th>valid_loss</th><th>accuracy</th><th>time</th></tr></thead><tbody><tr><td>0</td><td>2.093628</td><td>1.407563</td><td>0.616451</td><td>00:29</td></tr></tbody></table></div>
# <div><table class="fastprogress"><thead><tr><th>epoch</th><th>train_loss</th><th>valid_loss</th><th>accuracy</th><th>time</th></tr></thead><tbody><tr><td>0</td><td>1.201802</td><td>0.892091</td><td>0.755083</td><td>00:55</td></tr><tr><td>1</td><td>0.902382</td><td>0.789523</td><td>0.790665</td><td>00:57</td></tr><tr><td>2</td><td>0.767900</td><td>0.644739</td><td>0.825786</td><td>00:56</td></tr><tr><td>3</td><td>0.370397</td><td>0.614492</td><td>0.834104</td><td>00:56</td></tr><tr><td>4</td><td>0.299319</td><td>0.597096</td><td>0.844732</td><td>00:56</td></tr></tbody></table></div>

# %%
learn.export("legal_terms_conditions_model.pkl")
